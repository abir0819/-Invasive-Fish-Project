# %%
import pandas as pd

# Load CSV file into DataFrame
df = pd.read_csv(r"C:\Users\s8286460\OneDrive - Saint Marys University\Study Materials\GitHub\Machine-Learning-Projects\Fish Project\Nova_Scotia_Freshwater_Fish_Species_Distribution_Records.csv")


# View the resulting DataFrame
df.head()
# Out:
#       COUNTY  NAME  EASTING   NORTHING CAPTURE DATE SPECIES COMMON NAME  \
# 0  Annapolis  ALMA  332,331  4,942,630   06/06/1984         Brook Trout
# 1  Annapolis  ALMA  332,331  4,942,630   06/06/1984         White Perch
# 2  Annapolis  ALMA  332,331  4,942,630   06/06/1984        Yellow Perch
# 3  Annapolis  ALMA  332,331  4,942,630   06/06/1984      Brown Bullhead
# 4  Annapolis  ALMA  332,331  4,942,630   06/06/1984        American Eel
#
#   CAPTURE METHOD NAME              ORIGIN
# 0     100 ft gill net  Natural Occurrence
# 1     100 ft gill net  Natural Occurrence
# 2     100 ft gill net  Natural Occurrence
# 3     100 ft gill net  Natural Occurrence
# 4     100 ft gill net  Natural Occurrence

# %%
# Drop columns not needed
df.drop(['EASTING', 'NORTHING', 'CAPTURE DATE', 'CAPTURE METHOD NAME', 'COUNTY'], axis=1, inplace=True)

# Rename columns
df.rename(columns={'SPECIES COMMON NAME': 'Species', 'ORIGIN': 'Origin'}, inplace=True)

# %%
# View the resulting DataFrame
df.head()
# Out:
#    NAME         Species              Origin
# 0  ALMA     Brook Trout  Natural Occurrence
# 1  ALMA     White Perch  Natural Occurrence
# 2  ALMA    Yellow Perch  Natural Occurrence
# 3  ALMA  Brown Bullhead  Natural Occurrence
# 4  ALMA    American Eel  Natural Occurrence

# %%
df.shape
# Out:
# (5110, 3)

# %%
# Load CSV file for Latitude Longitude info
dfll = pd.read_csv('C:/Users/s8286460/OneDrive - Saint Marys University/Study Materials/GitHub/Machine-Learning-Projects/Fish Project/Latitude and Longitude.csv')

# View the resulting DataFrame
dfll.head()
# Out:
#     latitude   longitude
# 0   44.61747  -65.113344
# 1   44.61747  -65.113344
# 2   44.61747  -65.113344
# 3   44.61747  -65.113344
# 4   44.61747  -65.113344

# %%
df.shape
# Out:
# (5110, 3)

# %%
# Merge the DataFrames based on their index
merged_df = pd.merge(df, dfll, left_index=True, right_index=True)

# Display the resulting DataFrame
print(merged_df)
# Out:
#          NAME           Species              Origin   latitude   longitude
# 0        ALMA       Brook Trout  Natural Occurrence  44.617470  -65.113344
# 1        ALMA       White Perch  Natural Occurrence  44.617470  -65.113344
# 2        ALMA      Yellow Perch  Natural Occurrence  44.617470  -65.113344
# 3        ALMA    Brown Bullhead  Natural Occurrence  44.617470  -65.113344
# 4        ALMA      American Eel  Natural Occurrence  44.617470  -65.113344
# ...       ...               ...                 ...        ...         ...
# 5105  WILSONS       White Perch  Natural Occurrence  43.928559  -65.883312
# 5106  WILSONS      Yellow Perch  Natural Occurrence  43.928559  -65.883312
# 5107  WILSONS    Brown Bullhead  Natural Occurrence  43.928559  -65.883312
# 5108  WILSONS      White Sucker  Natural Occurrence  43.928559  -65.883312
# 5109  WILSONS  Banded Killifish  Natural Occurrence  43.928559  -65.883312
#
# [5110 rows x 5 columns]

# %%
merged_df.head()
# Out:
#    NAME         Species              Origin   latitude   longitude
# 0  ALMA     Brook Trout  Natural Occurrence   44.61747  -65.113344
# 1  ALMA     White Perch  Natural Occurrence   44.61747  -65.113344
# 2  ALMA    Yellow Perch  Natural Occurrence   44.61747  -65.113344
# 3  ALMA  Brown Bullhead  Natural Occurrence   44.61747  -65.113344
# 4  ALMA    American Eel  Natural Occurrence   44.61747  -65.113344

# %%
merged_df.drop_duplicates(subset=['NAME'], keep='first', inplace=True)
merged_df.shape
# Out:
# (833, 5)

# %%
# Export the DataFrame to a CSV file
#merged_df.to_csv('output_file.csv', index=False)

# %%
# Load CSV file into DataFrame
dfc = pd.read_csv(r"C:\Users\s8286460\OneDrive - Saint Marys University\Study Materials\GitHub\Machine-Learning-Projects\Fish Project\Nova_Scotia_Lake_Chemistry_Data.csv")

# View the resulting DataFrame
dfc.head()
# Out:
#        COUNTY  SITE_CODE LAKE_NAME STATION EASTING NORTHING TOPO_MAP MAPBOOK  \
# 0  Colchester       10.0     FOLLY     NaN  457386  5043110    11E12    28Z5
# 1  Colchester       10.0     FOLLY     NaN  457386  5043110    11E12    28Z5
# 2  Colchester       10.0     FOLLY     NaN  457386  5043110    11E12    28Z5
# 3  Colchester       10.0     FOLLY     NaN  457386  5043110    11E12    28Z5
# 4  Cumberland      989.0  HARRISON     NaN  400528  5062440    21H09    27X1
#
#   VOLUME__M3 SURFACE AREA_ha  ... ORGANIC CARBON TOTAL (mg/L)  \
# 0        NaN            78.9  ...                         2.3
# 1        NaN            78.9  ...                         1.7
# 2        NaN            78.9  ...                         NaN
# 3        NaN            78.9  ...                         2.0
# 4    2814528           134.4  ...                        10.1
#
#   DISSOLVED ORGANIC CARBON (mg/L) CHLOROPHYLL a (mg/m3) PHEOPHYTIN A (mg/m3)  \
# 0                             NaN                  1.43                 0.50
# 1                             NaN                   NaN                  NaN
# 2                             NaN                  0.87                 0.32
# 3                             NaN                   NaN                  NaN
# 4                             NaN                  8.45                 3.07
#
#                             LAB COLLECTOR  \
# 0  Nova Scotia Health Authority   bowencw
# 1  Nova Scotia Health Authority   bowencw
# 2  Nova Scotia Health Authority   bowencw
# 3  Nova Scotia Health Authority   bowencw
# 4  Nova Scotia Health Authority   bowencw
#
#                                      AGENCY  DATA_ID NOTES            ALT_NAME
# 0  NS Department of Fisheries & Aquaculture      NaN   NaN      FOLLY Folly R.
# 1  NS Department of Fisheries & Aquaculture      NaN   NaN      FOLLY Folly R.
# 2  NS Department of Fisheries & Aquaculture      NaN   NaN      FOLLY Folly R.
# 3  NS Department of Fisheries & Aquaculture      NaN   NaN      FOLLY Folly R.
# 4  NS Department of Fisheries & Aquaculture      NaN   NaN  HARRISON Maccan R.
#
# [5 rows x 61 columns]

# %%
dfc.shape
# Out:
# (2557, 61)

# %%
# Drop the specified columns
columns_to_drop = ['COUNTY', 'SITE_CODE', 'STATION', 'EASTING', 'NORTHING', 'TOPO_MAP', 'MAPBOOK', 'VOLUME__M3',
                   'SURFACE AREA_ha', 'MAXIMUM DEPTH_m', 'MEAN DEPTH_m', 'AREA LESS THAN 6M DEEP (ha)',
                   'SHORELINE DEVELOPMENT', 'FLUSHING RATE PER YEAR', 'HEADWATER', 'ASSESSMENT', 'SAMPLE DEPTH (m)',
                   '(JTU)TURBIDITY', 'COLOUR (TCU)', '(UNKNOWN UNITS)COLOUR', '(RELATIVE UNITS) COLOUR',
                   'TOTAL DISSOLVED SOLIDS (mg/L)', 'DISSOLVED ORGANIC CARBON (mg/L)', 'LAB', 'COLLECTOR',
                   'AGENCY', 'DATA_ID', 'NOTES', 'ALT_NAME']
dfc.drop(columns_to_drop, axis=1, inplace=True)

# %%
# Display the resulting DataFrame
dfc.head()
# Out:
#   LAKE_NAME THERMOCLIN  SURFACE TEMPERATURE (°C)  BOTTOM TEMPERATURE (°C)  \
# 0     FOLLY          S                      20.5                      6.2
# 1     FOLLY          S                      20.5                      6.2
# 2     FOLLY          T                      20.5                      6.2
# 3     FOLLY          B                      20.5                      6.2
# 4  HARRISON          S                      20.0                     19.7
#
#    SURFACE DISSOLVED OXYGEN (mg/L)  BOTTOM DISSOLVED OXYGEN (mg/L)  \
# 0                            13.28                            8.40
# 1                            13.28                            8.40
# 2                            13.28                            8.40
# 3                            13.28                            8.40
# 4                            12.11                           12.09
#
#    SECCHI_DISC_m  TURBIDITY (NTU) CONDUCTIVITY (umho/cm)  \
# 0            8.0             0.29                   54.5
# 1            8.0             0.22                   54.5
# 2            8.0              NaN                    NaN
# 3            8.0             0.91                   58.4
# 4            1.2             4.77                   52.4
#
#   HARDNESS as CaCO3 (mg/L)  ...  TOTAL NITROGEN as N (mg/L)  \
# 0                      NaN  ...                        0.12
# 1                      NaN  ...                        0.10
# 2                      NaN  ...                         NaN
# 3                        6  ...                        0.31
# 4                      9.6  ...                        0.35
#
#    NITRATE+ NITRITE as N  (mg/L)  AMMONIA as N (mg/L)  \
# 0                           0.01                 0.01
# 1                           0.02                 0.01
# 2                            NaN                  NaN
# 3                           0.03                 0.16
# 4                           0.01                 0.01
#
#    PHOSPHOROUS TOTAL  as P (mg/L) ORTHO PHOSPHOROUS as P (mg/L)  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                           0.009                         0.006
# 4                           0.021                         0.004
#
#    SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  ORGANIC CARBON TOTAL (mg/L)  \
# 0            2.1                     10.0                          2.3
# 1            2.4                     10.0                          1.7
# 2            NaN                      NaN                          NaN
# 3            3.4                      NaN                          2.0
# 4            1.5                     10.0                         10.1
#
#    CHLOROPHYLL a (mg/m3) PHEOPHYTIN A (mg/m3)
# 0                   1.43                 0.50
# 1                    NaN                  NaN
# 2                   0.87                 0.32
# 3                    NaN                  NaN
# 4                   8.45                 3.07
#
# [5 rows x 32 columns]

# %%
# List of column names to exclude which are already float64
exclude_cols = ['LAKE_NAME', 'THERMOCLIN', 'SURFACE TEMPERATURE (°C)', 'BOTTOM TEMPERATURE (°C)', 'SURFACE DISSOLVED OXYGEN (mg/L)', 'BOTTOM DISSOLVED OXYGEN (mg/L)', 'SECCHI_DISC_m', 'TURBIDITY (NTU)', 'ALKALINITY as CaCO3 (mg/L)', 'PH', 'ALUMINUM (mg/L)', 'CALCIUM(mg/L)', 'COPPER (mg/L)', 'IRON (mg/L)', 'MANGANESE (mg/L)', 'POTASSIUM (mg/L)', 'ZINC (mg/L)', 'TOTAL NITROGEN as N (mg/L)', 'NITRATE+ NITRITE as N  (mg/L)', 'AMMONIA as N (mg/L)', 'PHOSPHOROUS TOTAL  as P (mg/L)', 'ORTHO PHOSPHOROUS as P (mg/L)', 'SILICA (mg/L)', 'SUSPENDED SOLIDS (mg/L)', 'ORGANIC CARBON TOTAL (mg/L)', 'CHLOROPHYLL a (mg/m3)', 'PHEOPHYTIN A (mg/m3)']

# Convert columns to float64 type
for col in dfc.columns:
    if col not in exclude_cols:
        dfc[col] = pd.to_numeric(dfc[col], errors='coerce').astype('float64')

# %%
print(dfc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2557 entries, 0 to 2556
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LAKE_NAME                        2557 non-null   object
#  1   THERMOCLIN                       2557 non-null   object
#  2   SURFACE TEMPERATURE (°C)         1879 non-null   float64
#  3   BOTTOM TEMPERATURE (°C)          1814 non-null   float64
#  4   SURFACE DISSOLVED OXYGEN (mg/L)  1856 non-null   float64
#  5   BOTTOM DISSOLVED OXYGEN (mg/L)   1851 non-null   float64
#  6   SECCHI_DISC_m                    1814 non-null   float64
#  7   TURBIDITY (NTU)                  678 non-null    float64
#  8   CONDUCTIVITY (umho/cm)           2238 non-null   float64
#  9   HARDNESS as CaCO3 (mg/L)         1008 non-null   float64
#  10  ALKALINITY as CaCO3 (mg/L)       1785 non-null   float64
#  11  PH                               2456 non-null   float64
#  12  ALUMINUM (mg/L)                  1054 non-null   float64
#  13  CALCIUM(mg/L)                    1668 non-null   float64
#  14  CHLORIDE (mg/L)                  1612 non-null   float64
#  15  COPPER (mg/L)                    792 non-null    float64
#  16  IRON (mg/L)                      1430 non-null   float64
#  17  MANGANESE (mg/L)                 1430 non-null   float64
#  18  POTASSIUM (mg/L)                 1591 non-null   float64
#  19  SODIUM (mg/L)                    1624 non-null   float64
#  20  SULPHATE (mg/L)                  1462 non-null   float64
#  21  ZINC (mg/L)                      793 non-null    float64
#  22  TOTAL NITROGEN as N (mg/L)       1269 non-null   float64
#  23  NITRATE+ NITRITE as N  (mg/L)    1508 non-null   float64
#  24  AMMONIA as N (mg/L)              1457 non-null   float64
#  25  PHOSPHOROUS TOTAL  as P (mg/L)   1364 non-null   float64
#  26  ORTHO PHOSPHOROUS as P (mg/L)    1455 non-null   float64
#  27  SILICA (mg/L)                    675 non-null    float64
#  28  SUSPENDED SOLIDS (mg/L)          168 non-null    float64
#  29  ORGANIC CARBON TOTAL (mg/L)      1130 non-null   float64
#  30  CHLOROPHYLL a (mg/m3)            346 non-null    float64
#  31  PHEOPHYTIN A (mg/m3)             110 non-null    float64
# dtypes: float64(30), object(2)
# memory usage: 639.4+ KB
# None

# %%
# Replace NaN values with column means
dfc.fillna(dfc.mean(), inplace=True)
# Out:
# C:\Users\s8286460\AppData\Local\Temp\ipykernel_2336\440214110.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfc.fillna(dfc.mean(), inplace=True)

# %%
# Display the resulting DataFrame
dfc.head()
# Out:
#   LAKE_NAME THERMOCLIN  SURFACE TEMPERATURE (°C)  BOTTOM TEMPERATURE (°C)  \
# 0     FOLLY          S                      20.5                      6.2
# 1     FOLLY          S                      20.5                      6.2
# 2     FOLLY          T                      20.5                      6.2
# 3     FOLLY          B                      20.5                      6.2
# 4  HARRISON          S                      20.0                     19.7
#
#    SURFACE DISSOLVED OXYGEN (mg/L)  BOTTOM DISSOLVED OXYGEN (mg/L)  \
# 0                            13.28                            8.40
# 1                            13.28                            8.40
# 2                            13.28                            8.40
# 3                            13.28                            8.40
# 4                            12.11                           12.09
#
#    SECCHI_DISC_m  TURBIDITY (NTU)  CONDUCTIVITY (umho/cm)  \
# 0            8.0         0.290000               54.500000
# 1            8.0         0.220000               54.500000
# 2            8.0         2.316357               67.486336
# 3            8.0         0.910000               58.400000
# 4            1.2         4.770000               52.400000
#
#    HARDNESS as CaCO3 (mg/L)  ...  TOTAL NITROGEN as N (mg/L)  \
# 0                 12.830403  ...                    0.120000
# 1                 12.830403  ...                    0.100000
# 2                 12.830403  ...                    0.302196
# 3                  6.000000  ...                    0.310000
# 4                  9.600000  ...                    0.350000
#
#    NITRATE+ NITRITE as N  (mg/L)  AMMONIA as N (mg/L)  \
# 0                       0.010000             0.010000
# 1                       0.020000             0.010000
# 2                       0.027487             0.053384
# 3                       0.030000             0.160000
# 4                       0.010000             0.010000
#
#    PHOSPHOROUS TOTAL  as P (mg/L)  ORTHO PHOSPHOROUS as P (mg/L)  \
# 0                        0.053764                       0.035102
# 1                        0.053764                       0.035102
# 2                        0.053764                       0.035102
# 3                        0.009000                       0.006000
# 4                        0.021000                       0.004000
#
#    SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  ORGANIC CARBON TOTAL (mg/L)  \
# 0       2.100000                10.000000                      2.30000
# 1       2.400000                10.000000                      1.70000
# 2       1.588593                 4.705357                      6.01723
# 3       3.400000                 4.705357                      2.00000
# 4       1.500000                10.000000                     10.10000
#
#    CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)
# 0               1.430000                 0.500
# 1               4.805636                 2.132
# 2               0.870000                 0.320
# 3               4.805636                 2.132
# 4               8.450000                 3.070
#
# [5 rows x 32 columns]

# %%
#dfc.drop_duplicates(subset=['LAKE_NAME'], keep='first', inplace=True)

# %%
dfc = dfc.rename(columns={'LAKE_NAME': 'NAME'})

# %%
# Display the resulting DataFrame
dfc.head()
# Out:
#        NAME THERMOCLIN  SURFACE TEMPERATURE (°C)  BOTTOM TEMPERATURE (°C)  \
# 0     FOLLY          S                      20.5                      6.2
# 1     FOLLY          S                      20.5                      6.2
# 2     FOLLY          T                      20.5                      6.2
# 3     FOLLY          B                      20.5                      6.2
# 4  HARRISON          S                      20.0                     19.7
#
#    SURFACE DISSOLVED OXYGEN (mg/L)  BOTTOM DISSOLVED OXYGEN (mg/L)  \
# 0                            13.28                            8.40
# 1                            13.28                            8.40
# 2                            13.28                            8.40
# 3                            13.28                            8.40
# 4                            12.11                           12.09
#
#    SECCHI_DISC_m  TURBIDITY (NTU)  CONDUCTIVITY (umho/cm)  \
# 0            8.0         0.290000               54.500000
# 1            8.0         0.220000               54.500000
# 2            8.0         2.316357               67.486336
# 3            8.0         0.910000               58.400000
# 4            1.2         4.770000               52.400000
#
#    HARDNESS as CaCO3 (mg/L)  ...  TOTAL NITROGEN as N (mg/L)  \
# 0                 12.830403  ...                    0.120000
# 1                 12.830403  ...                    0.100000
# 2                 12.830403  ...                    0.302196
# 3                  6.000000  ...                    0.310000
# 4                  9.600000  ...                    0.350000
#
#    NITRATE+ NITRITE as N  (mg/L)  AMMONIA as N (mg/L)  \
# 0                       0.010000             0.010000
# 1                       0.020000             0.010000
# 2                       0.027487             0.053384
# 3                       0.030000             0.160000
# 4                       0.010000             0.010000
#
#    PHOSPHOROUS TOTAL  as P (mg/L)  ORTHO PHOSPHOROUS as P (mg/L)  \
# 0                        0.053764                       0.035102
# 1                        0.053764                       0.035102
# 2                        0.053764                       0.035102
# 3                        0.009000                       0.006000
# 4                        0.021000                       0.004000
#
#    SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  ORGANIC CARBON TOTAL (mg/L)  \
# 0       2.100000                10.000000                      2.30000
# 1       2.400000                10.000000                      1.70000
# 2       1.588593                 4.705357                      6.01723
# 3       3.400000                 4.705357                      2.00000
# 4       1.500000                10.000000                     10.10000
#
#    CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)
# 0               1.430000                 0.500
# 1               4.805636                 2.132
# 2               0.870000                 0.320
# 3               4.805636                 2.132
# 4               8.450000                 3.070
#
# [5 rows x 32 columns]

# %%
dfc.shape
# Out:
# (2557, 32)

# %%
merged_new = pd.merge(merged_df, dfc, on='NAME', how='inner')

# %%
# Display the resulting DataFrame
merged_new.head()
# Out:
#    NAME      Species              Origin   latitude   longitude THERMOCLIN  \
# 0  ALMA  Brook Trout  Natural Occurrence   44.61747  -65.113344          S
# 1  ALMA  Brook Trout  Natural Occurrence   44.61747  -65.113344          B
# 2  ALMA  Brook Trout  Natural Occurrence   44.61747  -65.113344          S
# 3  ALMA  Brook Trout  Natural Occurrence   44.61747  -65.113344          S
# 4  ALMA  Brook Trout  Natural Occurrence   44.61747  -65.113344          B
#
#    SURFACE TEMPERATURE (°C)  BOTTOM TEMPERATURE (°C)  \
# 0                  21.13289                14.294432
# 1                  21.13289                14.294432
# 2                  20.00000                 9.000000
# 3                  18.20000                15.200000
# 4                  18.20000                15.200000
#
#    SURFACE DISSOLVED OXYGEN (mg/L)  BOTTOM DISSOLVED OXYGEN (mg/L)  ...  \
# 0                         8.410426                        5.160756  ...
# 1                         8.410426                        5.160756  ...
# 2                         9.000000                        9.200000  ...
# 3                         9.000000                        8.000000  ...
# 4                         9.000000                        8.000000  ...
#
#    TOTAL NITROGEN as N (mg/L)  NITRATE+ NITRITE as N  (mg/L)  \
# 0                    0.190000                          0.010
# 1                    0.530000                          0.010
# 2                    0.302196                          0.025
# 3                    0.200000                          0.005
# 4                    0.200000                          0.005
#
#    AMMONIA as N (mg/L)  PHOSPHOROUS TOTAL  as P (mg/L)  \
# 0                0.010                        0.007000
# 1                0.160                        0.070000
# 2                0.025                        0.053764
# 3                0.005                        0.005000
# 4                0.005                        0.004000
#
#    ORTHO PHOSPHOROUS as P (mg/L)  SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  \
# 0                         0.0020       1.000000                 4.705357
# 1                         0.0400       5.400000                 4.705357
# 2                         0.0050       1.588593                 4.705357
# 3                         0.0005       1.588593                 4.705357
# 4                         0.0005       1.588593                 4.705357
#
#    ORGANIC CARBON TOTAL (mg/L)  CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)
# 0                      6.70000               4.000000                 2.132
# 1                     12.00000               4.805636                 2.132
# 2                      4.60000               4.805636                 2.132
# 3                      6.01723               4.805636                 2.132
# 4                      6.01723               4.805636                 2.132
#
# [5 rows x 36 columns]

# %%
merged_new.shape
# Out:
# (2153, 36)

# %%
merged_new = merged_new.rename(columns={'Origin': 'Present'})
cols = merged_new.columns.tolist()
cols.remove('Present')
cols.append('Present')
merged_new = merged_new[cols]

# %%
# Display the resulting DataFrame
merged_new.head()
# Out:
#    NAME      Species   latitude   longitude THERMOCLIN  \
# 0  ALMA  Brook Trout   44.61747  -65.113344          S
# 1  ALMA  Brook Trout   44.61747  -65.113344          B
# 2  ALMA  Brook Trout   44.61747  -65.113344          S
# 3  ALMA  Brook Trout   44.61747  -65.113344          S
# 4  ALMA  Brook Trout   44.61747  -65.113344          B
#
#    SURFACE TEMPERATURE (°C)  BOTTOM TEMPERATURE (°C)  \
# 0                  21.13289                14.294432
# 1                  21.13289                14.294432
# 2                  20.00000                 9.000000
# 3                  18.20000                15.200000
# 4                  18.20000                15.200000
#
#    SURFACE DISSOLVED OXYGEN (mg/L)  BOTTOM DISSOLVED OXYGEN (mg/L)  \
# 0                         8.410426                        5.160756
# 1                         8.410426                        5.160756
# 2                         9.000000                        9.200000
# 3                         9.000000                        8.000000
# 4                         9.000000                        8.000000
#
#    SECCHI_DISC_m  ...  NITRATE+ NITRITE as N  (mg/L)  AMMONIA as N (mg/L)  \
# 0       2.954909  ...                          0.010                0.010
# 1       2.954909  ...                          0.010                0.160
# 2       3.000000  ...                          0.025                0.025
# 3       1.750000  ...                          0.005                0.005
# 4       1.750000  ...                          0.005                0.005
#
#    PHOSPHOROUS TOTAL  as P (mg/L)  ORTHO PHOSPHOROUS as P (mg/L)  \
# 0                        0.007000                         0.0020
# 1                        0.070000                         0.0400
# 2                        0.053764                         0.0050
# 3                        0.005000                         0.0005
# 4                        0.004000                         0.0005
#
#    SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  ORGANIC CARBON TOTAL (mg/L)  \
# 0       1.000000                 4.705357                      6.70000
# 1       5.400000                 4.705357                     12.00000
# 2       1.588593                 4.705357                      4.60000
# 3       1.588593                 4.705357                      6.01723
# 4       1.588593                 4.705357                      6.01723
#
#    CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)             Present
# 0               4.000000                 2.132  Natural Occurrence
# 1               4.805636                 2.132  Natural Occurrence
# 2               4.805636                 2.132  Natural Occurrence
# 3               4.805636                 2.132  Natural Occurrence
# 4               4.805636                 2.132  Natural Occurrence
#
# [5 rows x 36 columns]

# %%
# Create a function to check if a species is invasive or not
def check_invasive(species):
    invasive_species = ["Chain Pickerel", "Yellow Perch", "White Perch", "Brown Bullhead", "Smallmouth Bass"]
    if species in invasive_species:
        return "1"
    else:
        return "0"

# Apply the check_invasive function to the "Species" column and create a new "Fish Type" column
merged_new["Invasive Fish"] = merged_new["Species"].apply(check_invasive)

# %%
merged_new.head()
# Out:
#    NAME      Species   latitude   longitude THERMOCLIN  \
# 0  ALMA  Brook Trout   44.61747  -65.113344          S
# 1  ALMA  Brook Trout   44.61747  -65.113344          B
# 2  ALMA  Brook Trout   44.61747  -65.113344          S
# 3  ALMA  Brook Trout   44.61747  -65.113344          S
# 4  ALMA  Brook Trout   44.61747  -65.113344          B
#
#    SURFACE TEMPERATURE (°C)  BOTTOM TEMPERATURE (°C)  \
# 0                  21.13289                14.294432
# 1                  21.13289                14.294432
# 2                  20.00000                 9.000000
# 3                  18.20000                15.200000
# 4                  18.20000                15.200000
#
#    SURFACE DISSOLVED OXYGEN (mg/L)  BOTTOM DISSOLVED OXYGEN (mg/L)  \
# 0                         8.410426                        5.160756
# 1                         8.410426                        5.160756
# 2                         9.000000                        9.200000
# 3                         9.000000                        8.000000
# 4                         9.000000                        8.000000
#
#    SECCHI_DISC_m  ...  AMMONIA as N (mg/L)  PHOSPHOROUS TOTAL  as P (mg/L)  \
# 0       2.954909  ...                0.010                        0.007000
# 1       2.954909  ...                0.160                        0.070000
# 2       3.000000  ...                0.025                        0.053764
# 3       1.750000  ...                0.005                        0.005000
# 4       1.750000  ...                0.005                        0.004000
#
#    ORTHO PHOSPHOROUS as P (mg/L)  SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  \
# 0                         0.0020       1.000000                 4.705357
# 1                         0.0400       5.400000                 4.705357
# 2                         0.0050       1.588593                 4.705357
# 3                         0.0005       1.588593                 4.705357
# 4                         0.0005       1.588593                 4.705357
#
#    ORGANIC CARBON TOTAL (mg/L)  CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)  \
# 0                      6.70000               4.000000                 2.132
# 1                     12.00000               4.805636                 2.132
# 2                      4.60000               4.805636                 2.132
# 3                      6.01723               4.805636                 2.132
# 4                      6.01723               4.805636                 2.132
#
#               Present  Invasive Fish
# 0  Natural Occurrence              0
# 1  Natural Occurrence              0
# 2  Natural Occurrence              0
# 3  Natural Occurrence              0
# 4  Natural Occurrence              0
#
# [5 rows x 37 columns]

# %%
merged_new.tail()
# Out:
#             NAME      Species   latitude   longitude THERMOCLIN  \
# 2148  WELLINGTON  Brook Trout  43.949981  -66.083338          S
# 2149  WELLINGTON  Brook Trout  43.949981  -66.083338          T
# 2150  WELLINGTON  Brook Trout  43.949981  -66.083338          B
# 2151  WELLINGTON  Brook Trout  43.949981  -66.083338          S
# 2152  WELLINGTON  Brook Trout  43.949981  -66.083338          B
#
#       SURFACE TEMPERATURE (°C)  BOTTOM TEMPERATURE (°C)  \
# 2148                  21.13289                14.294432
# 2149                  21.13289                14.294432
# 2150                  21.13289                14.294432
# 2151                  20.10000                13.300000
# 2152                  20.10000                13.300000
#
#       SURFACE DISSOLVED OXYGEN (mg/L)  BOTTOM DISSOLVED OXYGEN (mg/L)  \
# 2148                         8.410426                        5.160756
# 2149                         8.410426                        5.160756
# 2150                         8.410426                        5.160756
# 2151                         8.000000                        3.000000
# 2152                         8.000000                        3.000000
#
#       SECCHI_DISC_m  ...  AMMONIA as N (mg/L)  PHOSPHOROUS TOTAL  as P (mg/L)  \
# 2148       2.954909  ...                0.005                           0.006
# 2149       2.954909  ...                0.005                           0.009
# 2150       2.954909  ...                0.090                           0.019
# 2151       1.400000  ...                0.005                           0.006
# 2152       1.400000  ...                0.190                           0.019
#
#       ORTHO PHOSPHOROUS as P (mg/L)  SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  \
# 2148                          0.003       1.588593                 4.705357
# 2149                          0.002       1.588593                 4.705357
# 2150                          0.003       1.588593                 4.705357
# 2151                          0.001       1.588593                 4.705357
# 2152                          0.005       1.588593                 4.705357
#
#       ORGANIC CARBON TOTAL (mg/L)  CHLOROPHYLL a (mg/m3)  \
# 2148                          8.7               4.805636
# 2149                         10.0               4.805636
# 2150                         11.0               4.805636
# 2151                          8.7               4.805636
# 2152                         11.0               4.805636
#
#       PHEOPHYTIN A (mg/m3)             Present  Invasive Fish
# 2148                 2.132  Natural Occurrence              0
# 2149                 2.132  Natural Occurrence              0
# 2150                 2.132  Natural Occurrence              0
# 2151                 2.132  Natural Occurrence              0
# 2152                 2.132  Natural Occurrence              0
#
# [5 rows x 37 columns]

# %%
merged_new.shape
# Out:
# (2153, 37)

# %%
# drop the "Species" and "Present" columns and create a new DataFrame
df_final = merged_new.drop(["Species", "Present"], axis=1)

# %%
df_final.head()
# Out:
#    NAME   latitude   longitude THERMOCLIN  SURFACE TEMPERATURE (°C)  \
# 0  ALMA   44.61747  -65.113344          S                  21.13289
# 1  ALMA   44.61747  -65.113344          B                  21.13289
# 2  ALMA   44.61747  -65.113344          S                  20.00000
# 3  ALMA   44.61747  -65.113344          S                  18.20000
# 4  ALMA   44.61747  -65.113344          B                  18.20000
#
#    BOTTOM TEMPERATURE (°C)  SURFACE DISSOLVED OXYGEN (mg/L)  \
# 0                14.294432                         8.410426
# 1                14.294432                         8.410426
# 2                 9.000000                         9.000000
# 3                15.200000                         9.000000
# 4                15.200000                         9.000000
#
#    BOTTOM DISSOLVED OXYGEN (mg/L)  SECCHI_DISC_m  TURBIDITY (NTU)  ...  \
# 0                        5.160756       2.954909         0.830000  ...
# 1                        5.160756       2.954909         5.610000  ...
# 2                        9.200000       3.000000         0.850000  ...
# 3                        8.000000       1.750000         2.316357  ...
# 4                        8.000000       1.750000         2.316357  ...
#
#    NITRATE+ NITRITE as N  (mg/L)  AMMONIA as N (mg/L)  \
# 0                          0.010                0.010
# 1                          0.010                0.160
# 2                          0.025                0.025
# 3                          0.005                0.005
# 4                          0.005                0.005
#
#    PHOSPHOROUS TOTAL  as P (mg/L)  ORTHO PHOSPHOROUS as P (mg/L)  \
# 0                        0.007000                         0.0020
# 1                        0.070000                         0.0400
# 2                        0.053764                         0.0050
# 3                        0.005000                         0.0005
# 4                        0.004000                         0.0005
#
#    SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  ORGANIC CARBON TOTAL (mg/L)  \
# 0       1.000000                 4.705357                      6.70000
# 1       5.400000                 4.705357                     12.00000
# 2       1.588593                 4.705357                      4.60000
# 3       1.588593                 4.705357                      6.01723
# 4       1.588593                 4.705357                      6.01723
#
#    CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)  Invasive Fish
# 0               4.000000                 2.132              0
# 1               4.805636                 2.132              0
# 2               4.805636                 2.132              0
# 3               4.805636                 2.132              0
# 4               4.805636                 2.132              0
#
# [5 rows x 35 columns]

# %%
# convert "THERMOCLIN" column to numeric factor variable
df_final["THERMOCLIN"] = pd.factorize(df_final["THERMOCLIN"])[0]

# %%
df_final.head()
# Out:
#    NAME   latitude   longitude  THERMOCLIN  SURFACE TEMPERATURE (°C)  \
# 0  ALMA   44.61747  -65.113344           0                  21.13289
# 1  ALMA   44.61747  -65.113344           1                  21.13289
# 2  ALMA   44.61747  -65.113344           0                  20.00000
# 3  ALMA   44.61747  -65.113344           0                  18.20000
# 4  ALMA   44.61747  -65.113344           1                  18.20000
#
#    BOTTOM TEMPERATURE (°C)  SURFACE DISSOLVED OXYGEN (mg/L)  \
# 0                14.294432                         8.410426
# 1                14.294432                         8.410426
# 2                 9.000000                         9.000000
# 3                15.200000                         9.000000
# 4                15.200000                         9.000000
#
#    BOTTOM DISSOLVED OXYGEN (mg/L)  SECCHI_DISC_m  TURBIDITY (NTU)  ...  \
# 0                        5.160756       2.954909         0.830000  ...
# 1                        5.160756       2.954909         5.610000  ...
# 2                        9.200000       3.000000         0.850000  ...
# 3                        8.000000       1.750000         2.316357  ...
# 4                        8.000000       1.750000         2.316357  ...
#
#    NITRATE+ NITRITE as N  (mg/L)  AMMONIA as N (mg/L)  \
# 0                          0.010                0.010
# 1                          0.010                0.160
# 2                          0.025                0.025
# 3                          0.005                0.005
# 4                          0.005                0.005
#
#    PHOSPHOROUS TOTAL  as P (mg/L)  ORTHO PHOSPHOROUS as P (mg/L)  \
# 0                        0.007000                         0.0020
# 1                        0.070000                         0.0400
# 2                        0.053764                         0.0050
# 3                        0.005000                         0.0005
# 4                        0.004000                         0.0005
#
#    SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  ORGANIC CARBON TOTAL (mg/L)  \
# 0       1.000000                 4.705357                      6.70000
# 1       5.400000                 4.705357                     12.00000
# 2       1.588593                 4.705357                      4.60000
# 3       1.588593                 4.705357                      6.01723
# 4       1.588593                 4.705357                      6.01723
#
#    CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)  Invasive Fish
# 0               4.000000                 2.132              0
# 1               4.805636                 2.132              0
# 2               4.805636                 2.132              0
# 3               4.805636                 2.132              0
# 4               4.805636                 2.132              0
#
# [5 rows x 35 columns]

# %%
# find unique values of "THERMOCLIN" column
df_final["THERMOCLIN"].unique()

# print the unique values
#print(thermoclin_unique)
# Out:
# array([0, 1, 2], dtype=int64)

# %% [markdown]
# # Machine Learning Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\s8286460\anaconda3\lib\site-packages (22.2.2)
# Collecting pip
#   Downloading pip-23.1.2-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# Successfully installed pip-23.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Installing the required libraries

# Import all the tools we need

#Regular EDA and plotting libraries

import matplotlib.pyplot as plt

import seaborn as sns

# !pip install scikit-learn


# Models from Scikit-Learn

from sklearn.linear_model import LogisticRegression

from sklearn.neighbors import KNeighborsClassifier

from sklearn.ensemble import RandomForestClassifier


# Model Evaluations

from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

from sklearn.metrics import confusion_matrix, classification_report

from sklearn.metrics import precision_score, recall_score, f1_score

from sklearn.metrics import roc_curve, auc
# Out:
# Requirement already satisfied: scikit-learn in c:\users\s8286460\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\s8286460\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\s8286460\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\s8286460\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\s8286460\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
# Let's see how many positive (1) and negative (0) samples we have in our dataframe
class_counts = df_final['Invasive Fish'].value_counts()

# Plot the value counts with a bar graph
ax = class_counts.plot(kind="bar", color=["salmon", "lightblue"])

# Add title to the plot
plt.title("Class Check")
plt.xlabel("Invasive Fish Signal")
plt.ylabel("Amount")
#plt.legend(['Not Present','Present']);
plt.xticks(rotation = 2)

# Show the plot
plt.show()

# %%
# Checking summary statistics of dataframe

df_final.describe()
# Out:
#           latitude    longitude   THERMOCLIN  SURFACE TEMPERATURE (°C)  \
# count  2153.000000  2153.000000  2153.000000               2153.000000
# mean     44.808341   -63.883392     0.359034                 21.221927
# std       0.587491     1.666514     0.640728                  2.926204
# min      43.597834   -66.144195     0.000000                  0.800000
# 25%      44.350564   -65.281584     0.000000                 20.600000
# 50%      44.746224   -63.877922     0.000000                 21.132890
# 75%      45.141837   -62.864560     1.000000                 22.800000
# max      46.869400   -59.916622     2.000000                 28.700000
#
#        BOTTOM TEMPERATURE (°C)  SURFACE DISSOLVED OXYGEN (mg/L)  \
# count              2153.000000                      2153.000000
# mean                 14.343512                         8.446307
# std                   4.350721                         1.347764
# min                   3.500000                         0.000000
# 25%                  12.000000                         8.000000
# 50%                  14.294432                         8.410426
# 75%                  17.000000                         9.000000
# max                  28.000000                        16.000000
#
#        BOTTOM DISSOLVED OXYGEN (mg/L)  SECCHI_DISC_m  TURBIDITY (NTU)  \
# count                     2153.000000    2153.000000      2153.000000
# mean                         5.160859       2.996833         2.371232
# std                          2.765942       1.507851         2.945556
# min                          0.000000       0.100000         0.050000
# 25%                          3.200000       2.050000         2.316357
# 50%                          5.160756       2.954909         2.316357
# 75%                          7.000000       3.500000         2.316357
# max                         13.000000      12.000000        71.000000
#
#        CONDUCTIVITY (umho/cm)  ...  TOTAL NITROGEN as N (mg/L)  \
# count             2153.000000  ...                 2153.000000
# mean                64.256431  ...                    0.303007
# std                 78.740838  ...                    0.555230
# min                  5.800000  ...                    0.008000
# 25%                 29.100000  ...                    0.210000
# 50%                 44.000000  ...                    0.302196
# 75%                 67.486336  ...                    0.302196
# max                900.000000  ...                   22.500000
#
#        NITRATE+ NITRITE as N  (mg/L)  AMMONIA as N (mg/L)  \
# count                    2153.000000          2153.000000
# mean                        0.026395             0.055663
# std                         0.057994             0.204536
# min                         0.001000             0.002500
# 25%                         0.005000             0.007000
# 50%                         0.025000             0.030000
# 75%                         0.027487             0.053384
# max                         1.600000             4.520000
#
#        PHOSPHOROUS TOTAL  as P (mg/L)  ORTHO PHOSPHOROUS as P (mg/L)  \
# count                     2153.000000                    2153.000000
# mean                         0.056654                       0.037997
# std                          0.280532                       0.224301
# min                          0.000500                       0.000500
# 25%                          0.005000                       0.001000
# 50%                          0.040000                       0.005000
# 75%                          0.053764                       0.035102
# max                          5.200000                       4.060000
#
#        SILICA (mg/L)  SUSPENDED SOLIDS (mg/L)  ORGANIC CARBON TOTAL (mg/L)  \
# count    2153.000000              2153.000000                  2153.000000
# mean        1.594802                 4.752147                     5.969751
# std         0.656731                 1.629610                     2.402774
# min         0.050000                 0.150000                     0.250000
# 25%         1.588593                 4.705357                     5.600000
# 50%         1.588593                 4.705357                     6.017230
# 75%         1.588593                 4.705357                     6.017230
# max         6.800000                25.000000                    31.800000
#
#        CHLOROPHYLL a (mg/m3)  PHEOPHYTIN A (mg/m3)
# count            2153.000000           2153.000000
# mean                4.904202              2.132556
# std                 4.231631              0.778392
# min                 0.050000              0.010000
# 25%                 4.805636              2.132000
# 50%                 4.805636              2.132000
# 75%                 4.805636              2.132000
# max                90.000000             28.000000
#
# [8 rows x 33 columns]

# %%
df_final['Invasive Fish'] = df_final['Invasive Fish'].astype(int)

# %%
# Find the correlation between our independent variables

corr_matrix = df_final.corr()

fig, ax = plt.subplots(figsize=(25, 20))

sns.heatmap(corr_matrix,
            annot=True,
            linewidths=0.5,
            fmt= ".2f",
            cmap="YlGnBu");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (34.5, -0.5)

# %%
# Visualizing Invasive Fish presence

# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      -------------------------------------- 102.3/102.3 kB 1.5 MB/s eta 0:00:00
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\s8286460\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\s8286460\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in c:\users\s8286460\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\s8286460\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\s8286460\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\s8286460\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\s8286460\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\s8286460\anaconda3\lib\site-packages (from requests->folium) (2022.9.14)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
import folium

# Create the base map with the center at the coordinates you want
m = folium.Map(location=[44.6923, -62.6572], zoom_start=7.5)

# Add markers for each data point in the dataframe
for index, row in df_final.iterrows():
    if row['Invasive Fish'] == 1:
        marker_color = 'red'
    else:
        marker_color = 'blue'
        
    # Add a circle marker to the map
    folium.CircleMarker(location=[row[' latitude'], row[' longitude']],
                        radius=8,
                        color=marker_color,
                        fill=True,
                        fill_color=marker_color).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc634e159c40b57dd16eb9d3d03c21a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc634e159c40b57dd16eb9d3d03c21a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc634e159c40b57dd16eb9d3d03c21a0 = L.map(
#                 &quot;map_cc634e159c40b57dd16eb9d3d03c21a0&quot;,
#                 {
#                     center: [44.6923, -62.6572],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fca4f71753a56cb4ef7e5efdd9158579 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cc634e159c40b57dd16eb9d3d03c21a0);
#
#
#             var circle_marker_b196c34b2fdec0afa413173b9baf28ef = L.circleMarker(
#                 [44.61747021, -65.11334442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc634e159c40b57dd16eb9d3d03c21a0);
#
#
#             var circle_marker_128181b8a3d2ae03eaa143ce4d53ad97 = L.circleMarker(
#                 [44.61747021, -65.11334442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc634e159c40b57dd16eb9d3d03c21a0);
#
#
#             var circle_marker_0787e3bb8b69eb99e3822a63123ca814 = L.circleMarker(
#                 [44.61747021, -65.11334442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc634e159c40b57dd16eb9d3d03c21a0);
#
#
#             var circle_marker_a7e93969cb8aa57f5b3d91108a0ef0b4 = L.circleMarker(
#                 [44.61747021, -65.11334442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc634e159c40b57dd16eb9d3d03c21a0);
#
#
#             var circle_marker_8f7c563737d37428029c18ef298fa691 = L.circleMarker(
#                 [44.61747021, -65.11334442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc634e159c40b57dd16eb9d3d03c21a0);
#
#
#             var circle_marker_081c2b741f13a7a6168f9113de4f1c87 = L.circleMarker(
#                 [44.59785927, -65.47956774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc634e159c40b57dd16eb9d3d03c21a0);
#
#
#             var circle_marker_0eb31e42fe42e00fbc1e45272a009296 = L.circleMarker(

# %%
df_final.columns
# Out:
# Index(['NAME', ' latitude', ' longitude', 'THERMOCLIN',
#        'SURFACE TEMPERATURE (°C)', 'BOTTOM TEMPERATURE (°C)',
#        'SURFACE DISSOLVED OXYGEN (mg/L)', 'BOTTOM DISSOLVED OXYGEN (mg/L)',
#        'SECCHI_DISC_m', 'TURBIDITY (NTU)', 'CONDUCTIVITY (umho/cm)',
#        'HARDNESS as CaCO3 (mg/L)', 'ALKALINITY as CaCO3 (mg/L)', 'PH',
#        'ALUMINUM (mg/L)', 'CALCIUM(mg/L)', 'CHLORIDE (mg/L)', 'COPPER (mg/L)',
#        'IRON (mg/L)', 'MANGANESE (mg/L)', 'POTASSIUM (mg/L)', 'SODIUM (mg/L)',
#        'SULPHATE (mg/L)', 'ZINC (mg/L)', 'TOTAL NITROGEN as N (mg/L)',
#        'NITRATE+ NITRITE as N  (mg/L)', 'AMMONIA as N (mg/L)',
#        'PHOSPHOROUS TOTAL  as P (mg/L)', 'ORTHO PHOSPHOROUS as P (mg/L)',
#        'SILICA (mg/L)', 'SUSPENDED SOLIDS (mg/L)',
#        'ORGANIC CARBON TOTAL (mg/L)', 'CHLOROPHYLL a (mg/m3)',
#        'PHEOPHYTIN A (mg/m3)', 'Invasive Fish'],
#       dtype='object')

# %%
df_final['Invasive Fish'].unique()
# Out:
# array([0, 1])

# %%
df_final = df_final.drop('NAME', axis=1)

# %%
# Split the dataset into X (features) and y (target)
X = df_final.drop('Invasive Fish', axis=1)
Y = df_final['Invasive Fish']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=50)

# %%
# Put models in a dictionary
models = {"KNN": KNeighborsClassifier(),
          "Logistic Regression": LogisticRegression(), 
          "Random Forest": RandomForestClassifier()}

# Create function to fit and score models
def fit_and_score(models, X_train, X_test, Y_train, Y_test):
    """
    Fits and evaluates given machine learning models.
    models : a dict of different Scikit-Learn machine learning models
    X_train : training data
    X_test : testing data
    Y_train : labels associated with training data
    Y_test : labels associated with test data
    """
    # Random seed for reproducible results
    np.random.seed(50)

    # Make a list to keep model scores
    model_scores = {}

    # Loop through models
    for name, model in models.items():
    
    #Fit the model to the data
        model.fit(X_train, Y_train)
        
    #Evaluate the model and append its score to model_scores
        model_scores[name] = model.score(X_test, Y_test)
    return model_scores

# %%
import numpy as np

# %%
model_scores = fit_and_score(models=models,
                             X_train=X_train,
                             X_test=X_test,
                             Y_train=Y_train,
                             Y_test=Y_test)
model_scores
# Out:
# {'KNN': 0.6635730858468677,
#  'Logistic Regression': 0.7540603248259861,
#  'Random Forest': 0.8375870069605569}

# %%
model_compare = pd.DataFrame(model_scores, index=['Accuracy'])

plt.figure(figsize=(8, 6))

# Set bar color
colors = ['#FFC107', '#03A9F4', '#4CAF50']

# Plot the bar chart
ax = model_compare.T.plot(kind='bar', color=colors)

# Set plot title, x-label, and y-label
plt.title('Model Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy')

# Set y-axis range and tick marks
plt.ylim(0.5, 1.0)
plt.yticks(np.arange(0.5, 1.0, 0.1))

# Display the legend
plt.legend(loc='upper right')

# Remove top and right spines
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)

# Add value labels to each bar
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=12, padding=8)

plt.show()

# %%
# create the classifier with n_estimators = 100

clf = RandomForestClassifier(n_estimators=100, random_state=0)

# fit the model to the training set

clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# view the feature scores

feature_scores = pd.Series(clf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores
# Out:
#  longitude                         0.189641
#  latitude                          0.124909
# CONDUCTIVITY (umho/cm)             0.055090
# PH                                 0.049566
# SURFACE TEMPERATURE (°C)           0.046724
# SECCHI_DISC_m                      0.045407
# BOTTOM TEMPERATURE (°C)            0.039861
# BOTTOM DISSOLVED OXYGEN (mg/L)     0.032902
# SODIUM (mg/L)                      0.032415
# SURFACE DISSOLVED OXYGEN (mg/L)    0.029234
# ALKALINITY as CaCO3 (mg/L)         0.027027
# CALCIUM(mg/L)                      0.026910
# POTASSIUM (mg/L)                   0.026239
# CHLORIDE (mg/L)                    0.025922
# HARDNESS as CaCO3 (mg/L)           0.024434
# SULPHATE (mg/L)                    0.021980
# TOTAL NITROGEN as N (mg/L)         0.020126
# MANGANESE (mg/L)                   0.019975
# ALUMINUM (mg/L)                    0.019858
# IRON (mg/L)                        0.018623
# ORGANIC CARBON TOTAL (mg/L)        0.018175
# PHOSPHOROUS TOTAL  as P (mg/L)     0.017722
# TURBIDITY (NTU)                    0.013985
# AMMONIA as N (mg/L)                0.012613
# SILICA (mg/L)                      0.010354
# ORTHO PHOSPHOROUS as P (mg/L)      0.010052
# NITRATE+ NITRITE as N  (mg/L)      0.008898
# COPPER (mg/L)                      0.008670
# CHLOROPHYLL a (mg/m3)              0.008287
# ZINC (mg/L)                        0.006447
# THERMOCLIN                         0.003689
# PHEOPHYTIN A (mg/m3)               0.002351
# SUSPENDED SOLIDS (mg/L)            0.001914
# dtype: float64

# %%
# Set the figure size

plt.figure(figsize=(8, 7))

# Create a horizontal bar graph of feature importances

feature_scores.plot(kind='barh')

# Set the title and axis labels

plt.title('Feature Importances')

plt.xlabel('Importance Score')

plt.ylabel('Features')


# Show the plot

plt.show()

# %%
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(df_final.drop('Invasive Fish', axis=1), df_final['Invasive Fish'], test_size=0.2, random_state=42)

# Create a random forest classifier with 100 trees
rfc = RandomForestClassifier(n_estimators=100, random_state=50)

# Train the model on the training data
rfc.fit(X_train, Y_train)

# Evaluate the model on the testing data
accuracy = rfc.score(X_test, Y_test)

# Print the accuracy score
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8306264501160093

# %%
# Make predictions on new data
predictions = rfc.predict(df_final)


# Print the new data frame
print(df_predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2336\3157266915.py in <module>
#       1 # Make predictions on new data
# ----> 2 predictions = rfc.predict(df_final)
#       3
#       4
#       5 # Print the new data frame
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     806             The predicted classes.
#     807         """
# --> 808         proba = self.predict_proba(X)
#     809
#     810         if self.n_outputs_ == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     848         check_is_fitted(self)
#     849         # Check data
# --> 850         X = self._validate_X_predict(X)
#     851
#     852         # Assign chunk of trees to jobs
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     577         Validate X whenever one tries to predict, apply, predict_proba."""
#     578         check_is_fitted(self)
# --> 579         X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     580         if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     581             raise ValueError("No support for np.int64 index based sparse matrices")
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     398
#     399         if n_features != self.n_features_in_:
# --> 400             raise ValueError(
#     401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 34 features, but RandomForestClassifier is expecting 33 features as input.

# %%
# Copy df_final to a new dataframe dfn
#dfn = df_final.copy()

# Remove the 'Invasive Fish' column from dfn
#dfn.drop('Invasive Fish', axis=1, inplace=True)

# %%
# Make predictions on new data
#Pt = rfc.predict(dfn)

# Evaluate the predictions on the actual labels
#rr = rfc.score(dfn, df_final['Invasive Fish'])

# Print the accuracy score
#print("Accuracy:", rr)
